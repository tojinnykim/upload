# %%
import requests
import dotenv
import os
dotenv.load_dotenv()  # .env 환경변수 파일을 로드함

key = os.getenv("SEOUL_API")

# %%
url = 'http://openapi.seoul.go.kr:8088/'+key+'/json/VwsmMegaSelngW/1/1000/'
response = requests.get(url)
print(f'접속주소 : {response.url}')
print(f'응답코드 : {response.status_code}')
result = response.json()
# 보기쉽게 들여쓰기로 출력
import json
result = result['VwsmMegaSelngW']['row']
print(len(result))
print(json.dumps(result[0],indent=4,ensure_ascii=False))
# Out:
# 접속주소 : http://openapi.seoul.go.kr:8088/6e6f4867496a696e363768426a436c/json/VwsmMegaSelngW/1/1000/
# 응답코드 : 200
# 1000
# {
#     "STDR_YYQU_CD": "20243",
#     "MEGA_CD": "11",
#     "MEGA_CD_NM": "서울시",
#     "SVC_INDUTY_CD": "CS200005",
#     "SVC_INDUTY_CD_NM": "스포츠 강습",
#     "THSMON_SELNG_AMT": 125621989726.0,
#     "THSMON_SELNG_CO": 560552.0,
#     "MDWK_SELNG_AMT": 114839751900.0,
#     "WKEND_SELNG_AMT": 10782237826.0,
#     "MON_SELNG_AMT": 30659656338.0,
#     "TUES_SELNG_AMT": 22683014516.0,
#     "WED_SELNG_AMT": 19959596104.0,
#     "THUR_SELNG_AMT": 19905795231.0,
#     "FRI_SELNG_AMT": 21631689711.0,
#     "SAT_SELNG_AMT": 7980345220.0,
#     "SUN_SELNG_AMT": 2801892606.0,
#     "TMZON_00_06_SELNG_AMT": 313273700.0,
#     "TMZON_06_11_SELNG_AMT": 10780496989.0,
#     "TMZON_11_14_SELNG_AMT": 21717738293.0,
#     "TMZON_14_17_SELNG_AMT": 27194815821.0,
#     "TMZON_17_21_SELNG_AMT": 53891902018.0,
#     "TMZON_21_24_SELNG_AMT": 11723762905.0,
#     "ML_SELNG_AMT": 44909131421.0,
#     "FML_SELNG_AMT": 76391286774.0,
#     "AGRDE_10_SELNG_AMT": 264735815.0,
#     "AGRDE_20_SELNG_AMT": 14179488115.0,
#     "AGRDE_30_SELNG_AMT": 30537603201.0,
#     "AGRDE_40_SELNG_AMT": 48808297731.0,
#     "AGRDE_50_SELNG_AMT": 20404872792.0,
#     "AGRDE_60_ABOVE_SELNG_AMT": 7104969583.0,
#     "MDWK_SELNG_CO": 472987.0,
#     "WKEND_SELNG_CO": 87565.0,
#     "MON_SELNG_CO": 124015.0,
#     "TUES_SELNG_CO": 90482.0,
#     "WED_SELNG_CO": 86423.0,
#     "THUR_SELNG_CO": 81608.0,
#     "FRI_SELNG_CO": 90459.0,
#     "SAT_SELNG_CO": 51815.0,
#     "SUN_SELNG_CO": 35750.0,
#     "TMZON_00_06_SELNG_CO": 7645.0,
#     "TMZON_06_11_SELNG_CO": 48826.0,
#     "TMZON_11_14_SELNG_CO": 78575.0,
#     "TMZON_14_17_SELNG_CO": 135453.0,
#     "TMZON_17_21_SELNG_CO": 230966.0,
#     "TMZON_21_24_SELNG_CO": 59087.0,
#     "ML_SELNG_CO": 248918.0,
#     "FML_SELNG_CO": 300209.0,
#     "AGRDE_10_SELNG_CO": 10499.0,
#     "AGRDE_20_SELNG_CO": 73887.0,
#     "AGRDE_30_SELNG_CO": 124032.0,
#     "AGRDE_40_SELNG_CO": 237206.0,
#     "AGRDE_50_SELNG_CO": 76375.0,
#     "AGRDE_60_ABOVE_SELNG_CO": 27131.0
# }

# %%
import pandas as pd
df = pd.DataFrame(result)

column_mapping = {
    "STDR_YYQU_CD": "기준_년분기_코드",
    "MEGA_CD": "서울시_코드",
    "MEGA_CD_NM": "서울시_코드_명",
    "SVC_INDUTY_CD": "서비스_업종_코드",
    "SVC_INDUTY_CD_NM": "서비스_업종_코드_명",
    "THSMON_SELNG_AMT": "당월_매출_금액",
    "THSMON_SELNG_CO": "당월_매출_건수",
    "MDWK_SELNG_AMT": "주중_매출_금액",
    "WKEND_SELNG_AMT": "주말_매출_금액",
    "MON_SELNG_AMT": "월요일_매출_금액",
    "TUES_SELNG_AMT": "화요일_매출_금액",
    "WED_SELNG_AMT": "수요일_매출_금액",
    "THUR_SELNG_AMT": "목요일_매출_금액",
    "FRI_SELNG_AMT": "금요일_매출_금액",
    "SAT_SELNG_AMT": "토요일_매출_금액",
    "SUN_SELNG_AMT": "일요일_매출_금액",
    "TMZON_00_06_SELNG_AMT": "시간대_00~06_매출_금액",
    "TMZON_06_11_SELNG_AMT": "시간대_06~11_매출_금액",
    "TMZON_11_14_SELNG_AMT": "시간대_11~14_매출_금액",
    "TMZON_14_17_SELNG_AMT": "시간대_14~17_매출_금액",
    "TMZON_17_21_SELNG_AMT": "시간대_17~21_매출_금액",
    "TMZON_21_24_SELNG_AMT": "시간대_21~24_매출_금액",
    "ML_SELNG_AMT": "남성_매출_금액",
    "FML_SELNG_AMT": "여성_매출_금액",
    "AGRDE_10_SELNG_AMT": "연령대_10_매출_금액",
    "AGRDE_20_SELNG_AMT": "연령대_20_매출_금액",
    "AGRDE_30_SELNG_AMT": "연령대_30_매출_금액",
    "AGRDE_40_SELNG_AMT": "연령대_40_매출_금액",
    "AGRDE_50_SELNG_AMT": "연령대_50_매출_금액",
    "AGRDE_60_ABOVE_SELNG_AMT": "연령대_60_이상_매출_금액",
    "MDWK_SELNG_CO": "주중_매출_건수",
    "WKEND_SELNG_CO": "주말_매출_건수",
    "MON_SELNG_CO": "월요일_매출_건수",
    "TUES_SELNG_CO": "화요일_매출_건수",
    "WED_SELNG_CO": "수요일_매출_건수",
    "THUR_SELNG_CO": "목요일_매출_건수",
    "FRI_SELNG_CO": "금요일_매출_건수",
    "SAT_SELNG_CO": "토요일_매출_건수",
    "SUN_SELNG_CO": "일요일_매출_건수",
    "TMZON_00_06_SELNG_CO": "시간대_00~06_매출_건수",
    "TMZON_06_11_SELNG_CO": "시간대_06~11_매출_건수",
    "TMZON_11_14_SELNG_CO": "시간대_11~14_매출_건수",
    "TMZON_14_17_SELNG_CO": "시간대_14~17_매출_건수",
    "TMZON_17_21_SELNG_CO": "시간대_17~21_매출_건수",
    "TMZON_21_24_SELNG_CO": "시간대_21~24_매출_건수",
    "ML_SELNG_CO": "남성_매출_건수",
    "FML_SELNG_CO": "여성_매출_건수",
    "AGRDE_10_SELNG_CO": "연령대_10_매출_건수",
    "AGRDE_20_SELNG_CO": "연령대_20_매출_건수",
    "AGRDE_30_SELNG_CO": "연령대_30_매출_건수",
    "AGRDE_40_SELNG_CO": "연령대_40_매출_건수",
    "AGRDE_50_SELNG_CO": "연령대_50_매출_건수",
    "AGRDE_60_ABOVE_SELNG_CO": "연령대_60_이상_매출_건수"
}

df.rename(columns= column_mapping, inplace=True)
df.to_csv('seoul_store.csv',index=False,encoding='cp949')

# %%
df.set_index('기준_년분기_코드',inplace=True)

# %%
df.drop(columns=['서울시_코드','서울시_코드_명','서비스_업종_코드'],inplace=True)

# %%
df.head()
# Out:
#           서비스_업종_코드_명      당월_매출_금액     당월_매출_건수      주중_매출_금액      주말_매출_금액  \
# 기준_년분기_코드
# 20243          스포츠 강습  1.256220e+11     560552.0  1.148398e+11  1.078224e+10
# 20243              여관  6.684655e+10    1268476.0  4.588294e+10  2.096361e+10
# 20243             고시원  2.194135e+08        429.0  1.568745e+08  6.253908e+07
# 20243             편의점  1.131581e+12  165985978.0  8.347921e+11  2.967892e+11
# 20243            반찬가게  8.342301e+11   32501744.0  6.961403e+11  1.380897e+11
#
#               월요일_매출_금액     화요일_매출_금액     수요일_매출_금액     목요일_매출_금액  \
# 기준_년분기_코드
# 20243      3.065966e+10  2.268301e+10  1.995960e+10  1.990580e+10
# 20243      9.835197e+09  8.660760e+09  8.726616e+09  9.059335e+09
# 20243      5.600508e+07  1.862526e+07  1.862526e+07  3.180943e+07
# 20243      1.723568e+11  1.594869e+11  1.626247e+11  1.650212e+11
# 20243      1.574815e+11  1.266496e+11  1.375109e+11  1.304588e+11
#
#               금요일_매출_금액  ...  시간대_17~21_매출_건수  시간대_21~24_매출_건수     남성_매출_건수  \
# 기준_년분기_코드                ...
# 20243      2.163169e+10  ...         230966.0          59087.0     248918.0
# 20243      9.601032e+09  ...         354669.0         258571.0     869820.0
# 20243      3.180943e+07  ...             73.0            185.0        219.0
# 20243      1.753024e+11  ...       42140217.0       25755768.0  100792950.0
# 20243      1.440394e+11  ...        5866680.0        1246877.0   15357807.0
#
#              여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
# 기준_년분기_코드
# 20243        300209.0       10499.0       73887.0      124032.0      237206.0
# 20243        322857.0       18482.0      385561.0      328263.0      180558.0
# 20243           210.0           0.0         218.0         115.0           0.0
# 20243      63123710.0     3546395.0    37103083.0    46749462.0    33300287.0
# 20243      14937766.0      190358.0     3896771.0     7095865.0     6157793.0
#
#            연령대_50_매출_건수  연령대_60_이상_매출_건수
# 기준_년분기_코드
# 20243           76375.0          27131.0
# 20243          170101.0         109699.0
# 20243              96.0              0.0
# 20243        28146842.0       15070636.0
# 20243         6326482.0        6628285.0
#
# [5 rows x 49 columns]

# %%
# %pip install ipykernel jupyter
# Out:
# Requirement already satisfied: ipykernel in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (6.30.1)
# Requirement already satisfied: jupyter in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: appnope>=0.1.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: notebook in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter) (7.4.7)
# Requirement already satisfied: jupyter-console in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipywidgets in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter) (4.4.9)
# Requirement already satisfied: decorator in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: anyio in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from beautifulsoup4->nbconvert->jupyter) (4.14.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jinheekim/week_src/.venv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.columns
# Out:
# Index(['서비스_업종_코드_명', '당월_매출_금액', '당월_매출_건수', '주중_매출_금액', '주말_매출_금액',
#        '월요일_매출_금액', '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액',
#        '토요일_매출_금액', '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액',
#        '시간대_11~14_매출_금액', '시간대_14~17_매출_금액', '시간대_17~21_매출_금액',
#        '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액', '연령대_10_매출_금액',
#        '연령대_20_매출_금액', '연령대_30_매출_금액', '연령대_40_매출_금액', '연령대_50_매출_금액',
#        '연령대_60_이상_매출_금액', '주중_매출_건수', '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수',
#        '수요일_매출_건수', '목요일_매출_건수', '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수',
#        '시간대_00~06_매출_건수', '시간대_06~11_매출_건수', '시간대_11~14_매출_건수',
#        '시간대_14~17_매출_건수', '시간대_17~21_매출_건수', '시간대_21~24_매출_건수', '남성_매출_건수',
#        '여성_매출_건수', '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수',
#        '연령대_40_매출_건수', '연령대_50_매출_건수', '연령대_60_이상_매출_건수'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 20243 to 20221
# Data columns (total 49 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   서비스_업종_코드_명      1000 non-null   object
#  1   당월_매출_금액         1000 non-null   float64
#  2   당월_매출_건수         1000 non-null   float64
#  3   주중_매출_금액         1000 non-null   float64
#  4   주말_매출_금액         1000 non-null   float64
#  5   월요일_매출_금액        1000 non-null   float64
#  6   화요일_매출_금액        1000 non-null   float64
#  7   수요일_매출_금액        1000 non-null   float64
#  8   목요일_매출_금액        1000 non-null   float64
#  9   금요일_매출_금액        1000 non-null   float64
#  10  토요일_매출_금액        1000 non-null   float64
#  11  일요일_매출_금액        1000 non-null   float64
#  12  시간대_00~06_매출_금액  1000 non-null   float64
#  13  시간대_06~11_매출_금액  1000 non-null   float64
#  14  시간대_11~14_매출_금액  1000 non-null   float64
#  15  시간대_14~17_매출_금액  1000 non-null   float64
#  16  시간대_17~21_매출_금액  1000 non-null   float64
#  17  시간대_21~24_매출_금액  1000 non-null   float64
#  18  남성_매출_금액         1000 non-null   float64
#  19  여성_매출_금액         1000 non-null   float64
#  20  연령대_10_매출_금액     1000 non-null   float64
#  21  연령대_20_매출_금액     1000 non-null   float64
#  22  연령대_30_매출_금액     1000 non-null   float64
#  23  연령대_40_매출_금액     1000 non-null   float64
#  24  연령대_50_매출_금액     1000 non-null   float64
#  25  연령대_60_이상_매출_금액  1000 non-null   float64
#  26  주중_매출_건수         1000 non-null   float64
#  27  주말_매출_건수         1000 non-null   float64
#  28  월요일_매출_건수        1000 non-null   float64
#  29  화요일_매출_건수        1000 non-null   float64
#  30  수요일_매출_건수        1000 non-null   float64
#  31  목요일_매출_건수        1000 non-null   float64
#  32  금요일_매출_건수        1000 non-null   float64
#  33  토요일_매출_건수        1000 non-null   float64
#  34  일요일_매출_건수        1000 non-null   float64
#  35  시간대_00~06_매출_건수  1000 non-null   float64
#  36  시간대_06~11_매출_건수  1000 non-null   float64
#  37  시간대_11~14_매출_건수  1000 non-null   float64
#  38  시간대_14~17_매출_건수  1000 non-null   float64
#  39  시간대_17~21_매출_건수  1000 non-null   float64
#  40  시간대_21~24_매출_건수  1000 non-null   float64
#  41  남성_매출_건수         1000 non-null   float64
#  42  여성_매출_건수         1000 non-null   float64
#  43  연령대_10_매출_건수     1000 non-null   float64
#  44  연령대_20_매출_건수     1000 non-null   float64
#  45  연령대_30_매출_건수     1000 non-null   float64
#  46  연령대_40_매출_건수     1000 non-null   float64
#  47  연령대_50_매출_건수     1000 non-null   float64
#  48  연령대_60_이상_매출_건수  1000 non-null   float64
# dtypes: float64(48), object(1)
# memory usage: 390.6+ KB

# %%
df.describe()
# Out:
#            당월_매출_금액      당월_매출_건수      주중_매출_금액      주말_매출_금액     월요일_매출_금액  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   3.645979e+11  1.373949e+07  2.771861e+11  8.741173e+10  5.420283e+10
# std    5.270617e+11  2.878221e+07  3.978229e+11  1.432653e+11  7.754456e+10
# min    1.536038e+08  4.290000e+02  1.419959e+08  1.160782e+07  1.584308e+06
# 25%    5.709006e+10  6.500828e+05  4.278982e+10  1.159467e+10  8.446586e+09
# 50%    1.774707e+11  1.919724e+06  1.246345e+11  3.869445e+10  2.402137e+10
# 75%    4.196823e+11  1.299774e+07  3.461042e+11  9.392680e+10  6.345707e+10
# max    4.230012e+12  1.896340e+08  3.134427e+12  1.095585e+12  5.639798e+11
#
#           화요일_매출_금액     수요일_매출_금액     목요일_매출_금액     금요일_매출_금액     토요일_매출_금액  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   5.516536e+10  5.378295e+10  5.431037e+10  5.972461e+10  5.439469e+10
# std    7.921924e+10  7.723784e+10  7.894247e+10  8.701029e+10  8.424538e+10
# min    6.923077e+06  0.000000e+00  1.086392e+07  0.000000e+00  0.000000e+00
# 25%    8.097348e+09  8.468769e+09  8.617190e+09  8.768264e+09  7.781302e+09
# 50%    2.430754e+10  2.479007e+10  2.526955e+10  2.689430e+10  2.404055e+10
# 75%    6.677522e+10  6.368425e+10  6.721307e+10  7.194512e+10  6.028106e+10
# max    6.450126e+11  6.019207e+11  6.273000e+11  6.962139e+11  6.409869e+11
#
#        ...  시간대_17~21_매출_건수  시간대_21~24_매출_건수      남성_매출_건수      여성_매출_건수  \
# count  ...     1.000000e+03     1.000000e+03  1.000000e+03  1.000000e+03
# mean   ...     3.766050e+06     1.246678e+06  7.008232e+06  6.213343e+06
# std    ...     7.774921e+06     4.045672e+06  1.642095e+07  1.204166e+07
# min    ...     7.300000e+01     0.000000e+00  1.780000e+02  2.100000e+02
# 25%    ...     1.911308e+05     1.199800e+04  3.176125e+05  2.772355e+05
# 50%    ...     6.062785e+05     5.668300e+04  1.031907e+06  9.544820e+05
# 75%    ...     3.698946e+06     5.461862e+05  6.103115e+06  4.925839e+06
# max    ...     4.591302e+07     3.283053e+07  1.214085e+08  6.906399e+07
#
#        연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   2.461779e+05  2.986386e+06  3.019006e+06  2.688051e+06  2.372482e+06
# std    6.496761e+05  7.616007e+06  7.220232e+06  5.649216e+06  4.787093e+06
# min    0.000000e+00  1.430000e+02  0.000000e+00  0.000000e+00  9.600000e+01
# 25%    2.651000e+03  6.672550e+04  1.323788e+05  1.451842e+05  1.260785e+05
# 50%    1.677850e+04  3.588770e+05  3.495640e+05  4.111540e+05  4.094875e+05
# 75%    1.536975e+05  2.030412e+06  2.102068e+06  2.151602e+06  1.653128e+06
# max    5.554657e+06  6.568990e+07  5.106903e+07  3.623369e+07  2.814684e+07
#
#        연령대_60_이상_매출_건수
# count     1.000000e+03
# mean      1.909463e+06
# std       4.014891e+06
# min       0.000000e+00
# 25%       8.346550e+04
# 50%       2.693575e+05
# 75%       1.166834e+06
# max       2.434172e+07
#
# [8 rows x 48 columns]
